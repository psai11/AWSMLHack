# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch import nn
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score

# %%
df = pd.read_csv('dataset/train_clean_c0.csv')
df.head()
# Out:
#    Particulate_matter  SO2_concentration  O3_concentration  CO_concentration  \
# 0           -1.016712          -1.192496          0.461290         -1.357899
# 1           -1.037661          -0.834434          0.443937         -0.660369
# 2           -1.100509          -0.928905          0.426584         -0.945783
# 3           -1.110983          -0.566204          0.443937         -0.488062
# 4           -1.110983          -0.580403          0.322468         -0.593437
#
#    NO2_concentration   Presure  Dew_point  Precipitation  Anonymous_X1  \
# 0          -1.369288  1.192404  -1.699840      -0.081345     -1.939330
# 1          -0.619605  1.251684  -1.750820      -0.081345     -1.895684
# 2          -0.424172  1.271444  -1.932891      -0.081345     -0.155429
# 3          -0.990928  1.360364  -1.998436      -0.081345     -1.348701
# 4          -0.622602  1.449284  -1.925608      -0.081345     -0.732043
#
#    Wind_speed  Moisture_percent  Temperature  Datetime  ID
# 0    2.868591          0.993239    -1.235578  0.000000   0
# 1    1.509993          1.955098    -1.257531  0.000036   1
# 2    2.566681          2.186152    -1.296461  0.000071   2
# 3    2.264770          2.060491    -1.316548  0.000107   3
# 4    0.981649          2.098710    -1.358322  0.000143   4

# %%
df_ids = pd.DataFrame()
df_ids['ID'] = df['ID']
print(df_ids['ID'])

df = df.drop('ID', axis=1)
df.head()
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 27995    27995
# 27996    27996
# 27997    27997
# 27998    27998
# 27999    27999
# Name: ID, Length: 28000, dtype: int64
#    Particulate_matter  SO2_concentration  O3_concentration  CO_concentration  \
# 0           -1.016712          -1.192496          0.461290         -1.357899
# 1           -1.037661          -0.834434          0.443937         -0.660369
# 2           -1.100509          -0.928905          0.426584         -0.945783
# 3           -1.110983          -0.566204          0.443937         -0.488062
# 4           -1.110983          -0.580403          0.322468         -0.593437
#
#    NO2_concentration   Presure  Dew_point  Precipitation  Anonymous_X1  \
# 0          -1.369288  1.192404  -1.699840      -0.081345     -1.939330
# 1          -0.619605  1.251684  -1.750820      -0.081345     -1.895684
# 2          -0.424172  1.271444  -1.932891      -0.081345     -0.155429
# 3          -0.990928  1.360364  -1.998436      -0.081345     -1.348701
# 4          -0.622602  1.449284  -1.925608      -0.081345     -0.732043
#
#    Wind_speed  Moisture_percent  Temperature  Datetime
# 0    2.868591          0.993239    -1.235578  0.000000
# 1    1.509993          1.955098    -1.257531  0.000036
# 2    2.566681          2.186152    -1.296461  0.000071
# 3    2.264770          2.060491    -1.316548  0.000107
# 4    0.981649          2.098710    -1.358322  0.000143

# %%
X = df.drop('Temperature', axis=1).values
y = df['Temperature'].values

# %%
split_index = int(0.8 * len(X))  # First 80% for training

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (22400, 12)
# X_test shape: (5600, 12)
# y_train shape: (22400,)
# y_test shape: (5600,)

# %%
class weather_data:
    def __init__(self, X, y, scale_data=True):
        if not torch.is_tensor(X) and not torch.is_tensor(y):
            if scale_data:
                X = StandardScaler().fit_transform(X)
        self.X = torch.from_numpy(X)
        self.y = torch.from_numpy(y)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(12, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.layers(x)

# %%
if __name__=='__main__':
    torch.manual_seed(42)
    X,y = X, y

# %%
dataset = weather_data(X, y, scale_data=False)
trainloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=True)
testloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=True)

# %%
mlp = MLP()

loss_function = nn.L1Loss()
optimizer = torch.optim.Adagrad(mlp.parameters(), lr=1e-4)

# %%
for epoch in range(0,5):
    print(f'Starting Epoch {epoch+1}')

    current_loss = 0.0

    for i, data in enumerate(trainloader, 0):
        inputs, targets = data
        inputs, targets = inputs.float(), targets.float()
        targets = targets.reshape((targets.shape[0], 1))

        optimizer.zero_grad()

        outputs = mlp(inputs)

        loss = loss_function(outputs, targets)

        loss.backward()

        optimizer.step()

        current_loss += loss.item()

        if i%10 == 0:
            print(f'Loss after mini-batch %5d: %.3f'%(i+1, current_loss/500))
            current_loss = 0.0

    print(f'Epoch {epoch+1} finished')

print("Training has completed")
# Out:
# Starting Epoch 1
# Loss after mini-batch     1: 0.001
# Loss after mini-batch    11: 0.016
# Loss after mini-batch    21: 0.016
# Loss after mini-batch    31: 0.016
# Loss after mini-batch    41: 0.019
# Loss after mini-batch    51: 0.015
# Loss after mini-batch    61: 0.016
# Loss after mini-batch    71: 0.016
# Loss after mini-batch    81: 0.015
# Loss after mini-batch    91: 0.015
# Loss after mini-batch   101: 0.016
# Loss after mini-batch   111: 0.016
# Loss after mini-batch   121: 0.015
# Loss after mini-batch   131: 0.013
# Loss after mini-batch   141: 0.015
# Loss after mini-batch   151: 0.018
# Loss after mini-batch   161: 0.015
# Loss after mini-batch   171: 0.016
# Loss after mini-batch   181: 0.014
# Loss after mini-batch   191: 0.013
# Loss after mini-batch   201: 0.015
# Loss after mini-batch   211: 0.017
# Loss after mini-batch   221: 0.016
# Loss after mini-batch   231: 0.017
# Loss after mini-batch   241: 0.017
# Loss after mini-batch   251: 0.016
# Loss after mini-batch   261: 0.016
# Loss after mini-batch   271: 0.015
# Loss after mini-batch   281: 0.015
# Loss after mini-batch   291: 0.015
# Loss after mini-batch   301: 0.017
# Loss after mini-batch   311: 0.016
# Loss after mini-batch   321: 0.017
# Loss after mini-batch   331: 0.015
# Loss after mini-batch   341: 0.014
# Loss after mini-batch   351: 0.015
# Loss after mini-batch   361: 0.014
# Loss after mini-batch   371: 0.015
# Loss after mini-batch   381: 0.015
# Loss after mini-batch   391: 0.013
# Loss after mini-batch   401: 0.017
# Loss after mini-batch   411: 0.013
# Loss after mini-batch   421: 0.014
# Loss after mini-batch   431: 0.016
# Loss after mini-batch   441: 0.016
# Loss after mini-batch   451: 0.014
# Loss after mini-batch   461: 0.015
# Loss after mini-batch   471: 0.014
# Loss after mini-batch   481: 0.017
# Loss after mini-batch   491: 0.016
# Loss after mini-batch   501: 0.015
# Loss after mini-batch   511: 0.015
# Loss after mini-batch   521: 0.015
# Loss after mini-batch   531: 0.015
# Loss after mini-batch   541: 0.014
# Loss after mini-batch   551: 0.016
# Loss after mini-batch   561: 0.013
# Loss after mini-batch   571: 0.014
# Loss after mini-batch   581: 0.015
# Loss after mini-batch   591: 0.014
# Loss after mini-batch   601: 0.014
# Loss after mini-batch   611: 0.015
# Loss after mini-batch   621: 0.014
# Loss after mini-batch   631: 0.014
# Loss after mini-batch   641: 0.015
# Loss after mini-batch   651: 0.017
# Loss after mini-batch   661: 0.014
# Loss after mini-batch   671: 0.016
# Loss after mini-batch   681: 0.015
# Loss after mini-batch   691: 0.015
# Loss after mini-batch   701: 0.012
# Loss after mini-batch   711: 0.015
# Loss after mini-batch   721: 0.015
# Loss after mini-batch   731: 0.016
# Loss after mini-batch   741: 0.014
# Loss after mini-batch   751: 0.014
# Loss after mini-batch   761: 0.013
# Loss after mini-batch   771: 0.012
# Loss after mini-batch   781: 0.014
# Loss after mini-batch   791: 0.015
# Loss after mini-batch   801: 0.013
# Loss after mini-batch   811: 0.015
# Loss after mini-batch   821: 0.014
# Loss after mini-batch   831: 0.015
# Loss after mini-batch   841: 0.015
# Loss after mini-batch   851: 0.014
# Loss after mini-batch   861: 0.015
# Loss after mini-batch   871: 0.015
# Loss after mini-batch   881: 0.014
# Loss after mini-batch   891: 0.015
# Loss after mini-batch   901: 0.015
# Loss after mini-batch   911: 0.015
# Loss after mini-batch   921: 0.014
# Loss after mini-batch   931: 0.016
# Loss after mini-batch   941: 0.014
# Loss after mini-batch   951: 0.013
# Loss after mini-batch   961: 0.014
# Loss after mini-batch   971: 0.014
# Loss after mini-batch   981: 0.014
# Loss after mini-batch   991: 0.014
# Loss after mini-batch  1001: 0.014
# Loss after mini-batch  1011: 0.014
# Loss after mini-batch  1021: 0.015
# Loss after mini-batch  1031: 0.013
# Loss after mini-batch  1041: 0.014
# Loss after mini-batch  1051: 0.014
# Loss after mini-batch  1061: 0.012
# Loss after mini-batch  1071: 0.016
# Loss after mini-batch  1081: 0.014
# Loss after mini-batch  1091: 0.015
# Loss after mini-batch  1101: 0.015
# Loss after mini-batch  1111: 0.015
# Loss after mini-batch  1121: 0.014
# Loss after mini-batch  1131: 0.014
# Loss after mini-batch  1141: 0.014
# Loss after mini-batch  1151: 0.014
# Loss after mini-batch  1161: 0.012
# Loss after mini-batch  1171: 0.012
# Loss after mini-batch  1181: 0.014
# Loss after mini-batch  1191: 0.013
# Loss after mini-batch  1201: 0.014
# Loss after mini-batch  1211: 0.013
# Loss after mini-batch  1221: 0.015
# Loss after mini-batch  1231: 0.014
# Loss after mini-batch  1241: 0.014
# Loss after mini-batch  1251: 0.014
# Loss after mini-batch  1261: 0.015
# Loss after mini-batch  1271: 0.014
# Loss after mini-batch  1281: 0.012
# Loss after mini-batch  1291: 0.014
# Loss after mini-batch  1301: 0.014
# Loss after mini-batch  1311: 0.014
# Loss after mini-batch  1321: 0.014
# Loss after mini-batch  1331: 0.013
# Loss after mini-batch  1341: 0.013
# Loss after mini-batch  1351: 0.013
# Loss after mini-batch  1361: 0.012
# Loss after mini-batch  1371: 0.013
# Loss after mini-batch  1381: 0.013
# Loss after mini-batch  1391: 0.013
# Loss after mini-batch  1401: 0.013
# Loss after mini-batch  1411: 0.013
# Loss after mini-batch  1421: 0.014
# Loss after mini-batch  1431: 0.015
# Loss after mini-batch  1441: 0.014
# Loss after mini-batch  1451: 0.013
# Loss after mini-batch  1461: 0.014
# Loss after mini-batch  1471: 0.015
# Loss after mini-batch  1481: 0.013
# Loss after mini-batch  1491: 0.014
# Loss after mini-batch  1501: 0.014
# Loss after mini-batch  1511: 0.014
# Loss after mini-batch  1521: 0.014
# Loss after mini-batch  1531: 0.013
# Loss after mini-batch  1541: 0.014
# Loss after mini-batch  1551: 0.013
# Loss after mini-batch  1561: 0.013
# Loss after mini-batch  1571: 0.014
# Loss after mini-batch  1581: 0.015
# Loss after mini-batch  1591: 0.013
# Loss after mini-batch  1601: 0.015
# Loss after mini-batch  1611: 0.012
# Loss after mini-batch  1621: 0.017
# Loss after mini-batch  1631: 0.013
# Loss after mini-batch  1641: 0.013
# Loss after mini-batch  1651: 0.013
# Loss after mini-batch  1661: 0.014
# Loss after mini-batch  1671: 0.013
# Loss after mini-batch  1681: 0.014
# Loss after mini-batch  1691: 0.014
# Loss after mini-batch  1701: 0.013
# Loss after mini-batch  1711: 0.012
# Loss after mini-batch  1721: 0.014
# Loss after mini-batch  1731: 0.014
# Loss after mini-batch  1741: 0.012
# Loss after mini-batch  1751: 0.013
# Loss after mini-batch  1761: 0.013
# Loss after mini-batch  1771: 0.013
# Loss after mini-batch  1781: 0.014
# Loss after mini-batch  1791: 0.015
# Loss after mini-batch  1801: 0.013
# Loss after mini-batch  1811: 0.012
# Loss after mini-batch  1821: 0.014
# Loss after mini-batch  1831: 0.012
# Loss after mini-batch  1841: 0.013
# Loss after mini-batch  1851: 0.014
# Loss after mini-batch  1861: 0.013
# Loss after mini-batch  1871: 0.013
# Loss after mini-batch  1881: 0.012
# Loss after mini-batch  1891: 0.012
# Loss after mini-batch  1901: 0.014
# Loss after mini-batch  1911: 0.014
# Loss after mini-batch  1921: 0.012
# Loss after mini-batch  1931: 0.014
# Loss after mini-batch  1941: 0.015
# Loss after mini-batch  1951: 0.013
# Loss after mini-batch  1961: 0.013
# Loss after mini-batch  1971: 0.013
# Loss after mini-batch  1981: 0.013
# Loss after mini-batch  1991: 0.014
# Loss after mini-batch  2001: 0.013
# Loss after mini-batch  2011: 0.012
# Loss after mini-batch  2021: 0.013
# Loss after mini-batch  2031: 0.013
# Loss after mini-batch  2041: 0.013
# Loss after mini-batch  2051: 0.014
# Loss after mini-batch  2061: 0.013
# Loss after mini-batch  2071: 0.012
# Loss after mini-batch  2081: 0.014
# Loss after mini-batch  2091: 0.012
# Loss after mini-batch  2101: 0.015
# Loss after mini-batch  2111: 0.012
# Loss after mini-batch  2121: 0.012
# Loss after mini-batch  2131: 0.014
# Loss after mini-batch  2141: 0.012
# Loss after mini-batch  2151: 0.013
# Loss after mini-batch  2161: 0.012
# Loss after mini-batch  2171: 0.013
# Loss after mini-batch  2181: 0.013
# Loss after mini-batch  2191: 0.014
# Loss after mini-batch  2201: 0.012
# Loss after mini-batch  2211: 0.013
# Loss after mini-batch  2221: 0.012
# Loss after mini-batch  2231: 0.012
# Loss after mini-batch  2241: 0.014
# Loss after mini-batch  2251: 0.013
# Loss after mini-batch  2261: 0.013
# Loss after mini-batch  2271: 0.013
# Loss after mini-batch  2281: 0.013
# Loss after mini-batch  2291: 0.012
# Loss after mini-batch  2301: 0.014
# Loss after mini-batch  2311: 0.014
# Loss after mini-batch  2321: 0.013
# Loss after mini-batch  2331: 0.013
# Loss after mini-batch  2341: 0.013
# Loss after mini-batch  2351: 0.013
# Loss after mini-batch  2361: 0.012
# Loss after mini-batch  2371: 0.013
# Loss after mini-batch  2381: 0.013
# Loss after mini-batch  2391: 0.013
# Loss after mini-batch  2401: 0.014
# Loss after mini-batch  2411: 0.012
# Loss after mini-batch  2421: 0.012
# Loss after mini-batch  2431: 0.012
# Loss after mini-batch  2441: 0.011
# Loss after mini-batch  2451: 0.011
# Loss after mini-batch  2461: 0.013
# Loss after mini-batch  2471: 0.012
# Loss after mini-batch  2481: 0.013
# Loss after mini-batch  2491: 0.011
# Loss after mini-batch  2501: 0.013
# Loss after mini-batch  2511: 0.012
# Loss after mini-batch  2521: 0.012
# Loss after mini-batch  2531: 0.012
# Loss after mini-batch  2541: 0.011
# Loss after mini-batch  2551: 0.012
# Loss after mini-batch  2561: 0.013
# Loss after mini-batch  2571: 0.012
# Loss after mini-batch  2581: 0.013
# Loss after mini-batch  2591: 0.012
# Loss after mini-batch  2601: 0.013
# Loss after mini-batch  2611: 0.011
# Loss after mini-batch  2621: 0.012
# Loss after mini-batch  2631: 0.012
# Loss after mini-batch  2641: 0.011
# Loss after mini-batch  2651: 0.013
# Loss after mini-batch  2661: 0.012
# Loss after mini-batch  2671: 0.010
# Loss after mini-batch  2681: 0.013
# Loss after mini-batch  2691: 0.012
# Loss after mini-batch  2701: 0.013
# Loss after mini-batch  2711: 0.012
# Loss after mini-batch  2721: 0.012
# Loss after mini-batch  2731: 0.013
# Loss after mini-batch  2741: 0.012
# Loss after mini-batch  2751: 0.011
# Loss after mini-batch  2761: 0.012
# Loss after mini-batch  2771: 0.011
# Loss after mini-batch  2781: 0.011
# Loss after mini-batch  2791: 0.012
# Epoch 1 finished
# Starting Epoch 2
# Loss after mini-batch     1: 0.001
# Loss after mini-batch    11: 0.011
# Loss after mini-batch    21: 0.013
# Loss after mini-batch    31: 0.014
# Loss after mini-batch    41: 0.012
# Loss after mini-batch    51: 0.013
# Loss after mini-batch    61: 0.013
# Loss after mini-batch    71: 0.011
# Loss after mini-batch    81: 0.010
# Loss after mini-batch    91: 0.012
# Loss after mini-batch   101: 0.013
# Loss after mini-batch   111: 0.013
# Loss after mini-batch   121: 0.014
# Loss after mini-batch   131: 0.013
# Loss after mini-batch   141: 0.012
# Loss after mini-batch   151: 0.011
# Loss after mini-batch   161: 0.011
# Loss after mini-batch   171: 0.012
# Loss after mini-batch   181: 0.013
# Loss after mini-batch   191: 0.012
# Loss after mini-batch   201: 0.012
# Loss after mini-batch   211: 0.013
# Loss after mini-batch   221: 0.013
# Loss after mini-batch   231: 0.012
# Loss after mini-batch   241: 0.012
# Loss after mini-batch   251: 0.012
# Loss after mini-batch   261: 0.013
# Loss after mini-batch   271: 0.011
# Loss after mini-batch   281: 0.012
# Loss after mini-batch   291: 0.012
# Loss after mini-batch   301: 0.012
# Loss after mini-batch   311: 0.010
# Loss after mini-batch   321: 0.011
# Loss after mini-batch   331: 0.012
# Loss after mini-batch   341: 0.012
# Loss after mini-batch   351: 0.012
# Loss after mini-batch   361: 0.011
# Loss after mini-batch   371: 0.012
# Loss after mini-batch   381: 0.012
# Loss after mini-batch   391: 0.013
# Loss after mini-batch   401: 0.012
# Loss after mini-batch   411: 0.012
# Loss after mini-batch   421: 0.011
# Loss after mini-batch   431: 0.010
# Loss after mini-batch   441: 0.011
# Loss after mini-batch   451: 0.011
# Loss after mini-batch   461: 0.011
# Loss after mini-batch   471: 0.011
# Loss after mini-batch   481: 0.012
# Loss after mini-batch   491: 0.011
# Loss after mini-batch   501: 0.013
# Loss after mini-batch   511: 0.013
# Loss after mini-batch   521: 0.011
# Loss after mini-batch   531: 0.013
# Loss after mini-batch   541: 0.010
# Loss after mini-batch   551: 0.012
# Loss after mini-batch   561: 0.012
# Loss after mini-batch   571: 0.012
# Loss after mini-batch   581: 0.012
# Loss after mini-batch   591: 0.012
# Loss after mini-batch   601: 0.013
# Loss after mini-batch   611: 0.011
# Loss after mini-batch   621: 0.011
# Loss after mini-batch   631: 0.012
# Loss after mini-batch   641: 0.011
# Loss after mini-batch   651: 0.012
# Loss after mini-batch   661: 0.013
# Loss after mini-batch   671: 0.012
# Loss after mini-batch   681: 0.012
# Loss after mini-batch   691: 0.013
# Loss after mini-batch   701: 0.011
# Loss after mini-batch   711: 0.012
# Loss after mini-batch   721: 0.011
# Loss after mini-batch   731: 0.012
# Loss after mini-batch   741: 0.012
# Loss after mini-batch   751: 0.012
# Loss after mini-batch   761: 0.013
# Loss after mini-batch   771: 0.010
# Loss after mini-batch   781: 0.012
# Loss after mini-batch   791: 0.011
# Loss after mini-batch   801: 0.013
# Loss after mini-batch   811: 0.011
# Loss after mini-batch   821: 0.013
# Loss after mini-batch   831: 0.012
# Loss after mini-batch   841: 0.012
# Loss after mini-batch   851: 0.012
# Loss after mini-batch   861: 0.011
# Loss after mini-batch   871: 0.012
# Loss after mini-batch   881: 0.011
# Loss after mini-batch   891: 0.011
# Loss after mini-batch   901: 0.011
# Loss after mini-batch   911: 0.013
# Loss after mini-batch   921: 0.010
# Loss after mini-batch   931: 0.010
# Loss after mini-batch   941: 0.012
# Loss after mini-batch   951: 0.012
# Loss after mini-batch   961: 0.012
# Loss after mini-batch   971: 0.010
# Loss after mini-batch   981: 0.010
# Loss after mini-batch   991: 0.012
# Loss after mini-batch  1001: 0.012
# Loss after mini-batch  1011: 0.012
# Loss after mini-batch  1021: 0.012
# Loss after mini-batch  1031: 0.011
# Loss after mini-batch  1041: 0.012
# Loss after mini-batch  1051: 0.012
# Loss after mini-batch  1061: 0.010
# Loss after mini-batch  1071: 0.011
# Loss after mini-batch  1081: 0.012
# Loss after mini-batch  1091: 0.013
# Loss after mini-batch  1101: 0.010
# Loss after mini-batch  1111: 0.011
# Loss after mini-batch  1121: 0.012
# Loss after mini-batch  1131: 0.012
# Loss after mini-batch  1141: 0.010
# Loss after mini-batch  1151: 0.013
# Loss after mini-batch  1161: 0.012
# Loss after mini-batch  1171: 0.010
# Loss after mini-batch  1181: 0.012
# Loss after mini-batch  1191: 0.010
# Loss after mini-batch  1201: 0.011
# Loss after mini-batch  1211: 0.011
# Loss after mini-batch  1221: 0.010
# Loss after mini-batch  1231: 0.011
# Loss after mini-batch  1241: 0.012
# Loss after mini-batch  1251: 0.011
# Loss after mini-batch  1261: 0.010
# Loss after mini-batch  1271: 0.011
# Loss after mini-batch  1281: 0.010
# Loss after mini-batch  1291: 0.010
# Loss after mini-batch  1301: 0.011
# Loss after mini-batch  1311: 0.011
# Loss after mini-batch  1321: 0.011
# Loss after mini-batch  1331: 0.012
# Loss after mini-batch  1341: 0.010
# Loss after mini-batch  1351: 0.012
# Loss after mini-batch  1361: 0.011
# Loss after mini-batch  1371: 0.012
# Loss after mini-batch  1381: 0.010
# Loss after mini-batch  1391: 0.010
# Loss after mini-batch  1401: 0.010
# Loss after mini-batch  1411: 0.011
# Loss after mini-batch  1421: 0.011
# Loss after mini-batch  1431: 0.011
# Loss after mini-batch  1441: 0.012
# Loss after mini-batch  1451: 0.011
# Loss after mini-batch  1461: 0.010
# Loss after mini-batch  1471: 0.011
# Loss after mini-batch  1481: 0.012
# Loss after mini-batch  1491: 0.011
# Loss after mini-batch  1501: 0.011
# Loss after mini-batch  1511: 0.010
# Loss after mini-batch  1521: 0.011
# Loss after mini-batch  1531: 0.010
# Loss after mini-batch  1541: 0.012
# Loss after mini-batch  1551: 0.010
# Loss after mini-batch  1561: 0.011
# Loss after mini-batch  1571: 0.010
# Loss after mini-batch  1581: 0.010
# Loss after mini-batch  1591: 0.010
# Loss after mini-batch  1601: 0.011
# Loss after mini-batch  1611: 0.012
# Loss after mini-batch  1621: 0.011
# Loss after mini-batch  1631: 0.010
# Loss after mini-batch  1641: 0.011
# Loss after mini-batch  1651: 0.010
# Loss after mini-batch  1661: 0.011
# Loss after mini-batch  1671: 0.011
# Loss after mini-batch  1681: 0.012
# Loss after mini-batch  1691: 0.012
# Loss after mini-batch  1701: 0.010
# Loss after mini-batch  1711: 0.010
# Loss after mini-batch  1721: 0.011
# Loss after mini-batch  1731: 0.011
# Loss after mini-batch  1741: 0.010
# Loss after mini-batch  1751: 0.012
# Loss after mini-batch  1761: 0.012
# Loss after mini-batch  1771: 0.013
# Loss after mini-batch  1781: 0.011
# Loss after mini-batch  1791: 0.012
# Loss after mini-batch  1801: 0.010
# Loss after mini-batch  1811: 0.011
# Loss after mini-batch  1821: 0.011
# Loss after mini-batch  1831: 0.010
# Loss after mini-batch  1841: 0.012
# Loss after mini-batch  1851: 0.011
# Loss after mini-batch  1861: 0.011
# Loss after mini-batch  1871: 0.012
# Loss after mini-batch  1881: 0.012
# Loss after mini-batch  1891: 0.011
# Loss after mini-batch  1901: 0.011
# Loss after mini-batch  1911: 0.011
# Loss after mini-batch  1921: 0.010
# Loss after mini-batch  1931: 0.012
# Loss after mini-batch  1941: 0.011
# Loss after mini-batch  1951: 0.011
# Loss after mini-batch  1961: 0.011
# Loss after mini-batch  1971: 0.011
# Loss after mini-batch  1981: 0.011
# Loss after mini-batch  1991: 0.011
# Loss after mini-batch  2001: 0.012
# Loss after mini-batch  2011: 0.012
# Loss after mini-batch  2021: 0.009
# Loss after mini-batch  2031: 0.011
# Loss after mini-batch  2041: 0.009
# Loss after mini-batch  2051: 0.010
# Loss after mini-batch  2061: 0.011
# Loss after mini-batch  2071: 0.012
# Loss after mini-batch  2081: 0.010
# Loss after mini-batch  2091: 0.010
# Loss after mini-batch  2101: 0.011
# Loss after mini-batch  2111: 0.010
# Loss after mini-batch  2121: 0.012
# Loss after mini-batch  2131: 0.011
# Loss after mini-batch  2141: 0.011
# Loss after mini-batch  2151: 0.011
# Loss after mini-batch  2161: 0.010
# Loss after mini-batch  2171: 0.009
# Loss after mini-batch  2181: 0.011
# Loss after mini-batch  2191: 0.011
# Loss after mini-batch  2201: 0.012
# Loss after mini-batch  2211: 0.011
# Loss after mini-batch  2221: 0.012
# Loss after mini-batch  2231: 0.009
# Loss after mini-batch  2241: 0.010
# Loss after mini-batch  2251: 0.010
# Loss after mini-batch  2261: 0.012
# Loss after mini-batch  2271: 0.010
# Loss after mini-batch  2281: 0.010
# Loss after mini-batch  2291: 0.011
# Loss after mini-batch  2301: 0.011
# Loss after mini-batch  2311: 0.010
# Loss after mini-batch  2321: 0.011
# Loss after mini-batch  2331: 0.011
# Loss after mini-batch  2341: 0.010
# Loss after mini-batch  2351: 0.011
# Loss after mini-batch  2361: 0.010
# Loss after mini-batch  2371: 0.011
# Loss after mini-batch  2381: 0.011
# Loss after mini-batch  2391: 0.010
# Loss after mini-batch  2401: 0.009
# Loss after mini-batch  2411: 0.010
# Loss after mini-batch  2421: 0.010
# Loss after mini-batch  2431: 0.010
# Loss after mini-batch  2441: 0.011
# Loss after mini-batch  2451: 0.010
# Loss after mini-batch  2461: 0.011
# Loss after mini-batch  2471: 0.009
# Loss after mini-batch  2481: 0.011
# Loss after mini-batch  2491: 0.011
# Loss after mini-batch  2501: 0.010
# Loss after mini-batch  2511: 0.010
# Loss after mini-batch  2521: 0.011
# Loss after mini-batch  2531: 0.011
# Loss after mini-batch  2541: 0.010
# Loss after mini-batch  2551: 0.011
# Loss after mini-batch  2561: 0.010
# Loss after mini-batch  2571: 0.010
# Loss after mini-batch  2581: 0.011
# Loss after mini-batch  2591: 0.011
# Loss after mini-batch  2601: 0.009
# Loss after mini-batch  2611: 0.011
# Loss after mini-batch  2621: 0.009
# Loss after mini-batch  2631: 0.010
# Loss after mini-batch  2641: 0.011
# Loss after mini-batch  2651: 0.009
# Loss after mini-batch  2661: 0.009
# Loss after mini-batch  2671: 0.011
# Loss after mini-batch  2681: 0.011
# Loss after mini-batch  2691: 0.010
# Loss after mini-batch  2701: 0.010
# Loss after mini-batch  2711: 0.008
# Loss after mini-batch  2721: 0.011
# Loss after mini-batch  2731: 0.010
# Loss after mini-batch  2741: 0.010
# Loss after mini-batch  2751: 0.009
# Loss after mini-batch  2761: 0.009
# Loss after mini-batch  2771: 0.011
# Loss after mini-batch  2781: 0.010
# Loss after mini-batch  2791: 0.010
# Epoch 2 finished
# Starting Epoch 3
# Loss after mini-batch     1: 0.001
# Loss after mini-batch    11: 0.010
# Loss after mini-batch    21: 0.011
# Loss after mini-batch    31: 0.010
# Loss after mini-batch    41: 0.010
# Loss after mini-batch    51: 0.010
# Loss after mini-batch    61: 0.010
# Loss after mini-batch    71: 0.011
# Loss after mini-batch    81: 0.010
# Loss after mini-batch    91: 0.010
# Loss after mini-batch   101: 0.009
# Loss after mini-batch   111: 0.010
# Loss after mini-batch   121: 0.011
# Loss after mini-batch   131: 0.010
# Loss after mini-batch   141: 0.010
# Loss after mini-batch   151: 0.011
# Loss after mini-batch   161: 0.010
# Loss after mini-batch   171: 0.010
# Loss after mini-batch   181: 0.009
# Loss after mini-batch   191: 0.012
# Loss after mini-batch   201: 0.010
# Loss after mini-batch   211: 0.010
# Loss after mini-batch   221: 0.010
# Loss after mini-batch   231: 0.011
# Loss after mini-batch   241: 0.008
# Loss after mini-batch   251: 0.011
# Loss after mini-batch   261: 0.009
# Loss after mini-batch   271: 0.010
# Loss after mini-batch   281: 0.009
# Loss after mini-batch   291: 0.010
# Loss after mini-batch   301: 0.009
# Loss after mini-batch   311: 0.009
# Loss after mini-batch   321: 0.011
# Loss after mini-batch   331: 0.010
# Loss after mini-batch   341: 0.011
# Loss after mini-batch   351: 0.010
# Loss after mini-batch   361: 0.009
# Loss after mini-batch   371: 0.009
# Loss after mini-batch   381: 0.009
# Loss after mini-batch   391: 0.010
# Loss after mini-batch   401: 0.009
# Loss after mini-batch   411: 0.010
# Loss after mini-batch   421: 0.010
# Loss after mini-batch   431: 0.009
# Loss after mini-batch   441: 0.010
# Loss after mini-batch   451: 0.011
# Loss after mini-batch   461: 0.010
# Loss after mini-batch   471: 0.010
# Loss after mini-batch   481: 0.010
# Loss after mini-batch   491: 0.008
# Loss after mini-batch   501: 0.009
# Loss after mini-batch   511: 0.010
# Loss after mini-batch   521: 0.011
# Loss after mini-batch   531: 0.010
# Loss after mini-batch   541: 0.010
# Loss after mini-batch   551: 0.009
# Loss after mini-batch   561: 0.010
# Loss after mini-batch   571: 0.010
# Loss after mini-batch   581: 0.010
# Loss after mini-batch   591: 0.010
# Loss after mini-batch   601: 0.008
# Loss after mini-batch   611: 0.010
# Loss after mini-batch   621: 0.010
# Loss after mini-batch   631: 0.011
# Loss after mini-batch   641: 0.009
# Loss after mini-batch   651: 0.009
# Loss after mini-batch   661: 0.010
# Loss after mini-batch   671: 0.010
# Loss after mini-batch   681: 0.011
# Loss after mini-batch   691: 0.009
# Loss after mini-batch   701: 0.009
# Loss after mini-batch   711: 0.009
# Loss after mini-batch   721: 0.009
# Loss after mini-batch   731: 0.009
# Loss after mini-batch   741: 0.011
# Loss after mini-batch   751: 0.009
# Loss after mini-batch   761: 0.010
# Loss after mini-batch   771: 0.008
# Loss after mini-batch   781: 0.010
# Loss after mini-batch   791: 0.008
# Loss after mini-batch   801: 0.009
# Loss after mini-batch   811: 0.010
# Loss after mini-batch   821: 0.009
# Loss after mini-batch   831: 0.009
# Loss after mini-batch   841: 0.010
# Loss after mini-batch   851: 0.009
# Loss after mini-batch   861: 0.010
# Loss after mini-batch   871: 0.010
# Loss after mini-batch   881: 0.009
# Loss after mini-batch   891: 0.009
# Loss after mini-batch   901: 0.009
# Loss after mini-batch   911: 0.009
# Loss after mini-batch   921: 0.010
# Loss after mini-batch   931: 0.010
# Loss after mini-batch   941: 0.009
# Loss after mini-batch   951: 0.010
# Loss after mini-batch   961: 0.009
# Loss after mini-batch   971: 0.010
# Loss after mini-batch   981: 0.010
# Loss after mini-batch   991: 0.010
# Loss after mini-batch  1001: 0.009
# Loss after mini-batch  1011: 0.009
# Loss after mini-batch  1021: 0.008
# Loss after mini-batch  1031: 0.009
# Loss after mini-batch  1041: 0.010
# Loss after mini-batch  1051: 0.008
# Loss after mini-batch  1061: 0.010
# Loss after mini-batch  1071: 0.009
# Loss after mini-batch  1081: 0.009
# Loss after mini-batch  1091: 0.010
# Loss after mini-batch  1101: 0.009
# Loss after mini-batch  1111: 0.009
# Loss after mini-batch  1121: 0.010
# Loss after mini-batch  1131: 0.009
# Loss after mini-batch  1141: 0.009
# Loss after mini-batch  1151: 0.008
# Loss after mini-batch  1161: 0.010
# Loss after mini-batch  1171: 0.009
# Loss after mini-batch  1181: 0.008
# Loss after mini-batch  1191: 0.009
# Loss after mini-batch  1201: 0.009
# Loss after mini-batch  1211: 0.008
# Loss after mini-batch  1221: 0.008
# Loss after mini-batch  1231: 0.009
# Loss after mini-batch  1241: 0.008
# Loss after mini-batch  1251: 0.009
# Loss after mini-batch  1261: 0.008
# Loss after mini-batch  1271: 0.008
# Loss after mini-batch  1281: 0.009
# Loss after mini-batch  1291: 0.010
# Loss after mini-batch  1301: 0.008
# Loss after mini-batch  1311: 0.011
# Loss after mini-batch  1321: 0.010
# Loss after mini-batch  1331: 0.008
# Loss after mini-batch  1341: 0.010
# Loss after mini-batch  1351: 0.008
# Loss after mini-batch  1361: 0.010
# Loss after mini-batch  1371: 0.010
# Loss after mini-batch  1381: 0.009
# Loss after mini-batch  1391: 0.009
# Loss after mini-batch  1401: 0.008
# Loss after mini-batch  1411: 0.009
# Loss after mini-batch  1421: 0.008
# Loss after mini-batch  1431: 0.009
# Loss after mini-batch  1441: 0.008
# Loss after mini-batch  1451: 0.008
# Loss after mini-batch  1461: 0.010
# Loss after mini-batch  1471: 0.008
# Loss after mini-batch  1481: 0.011
# Loss after mini-batch  1491: 0.008
# Loss after mini-batch  1501: 0.008
# Loss after mini-batch  1511: 0.009
# Loss after mini-batch  1521: 0.009
# Loss after mini-batch  1531: 0.008
# Loss after mini-batch  1541: 0.009
# Loss after mini-batch  1551: 0.008
# Loss after mini-batch  1561: 0.008
# Loss after mini-batch  1571: 0.009
# Loss after mini-batch  1581: 0.008
# Loss after mini-batch  1591: 0.010
# Loss after mini-batch  1601: 0.009
# Loss after mini-batch  1611: 0.011
# Loss after mini-batch  1621: 0.009
# Loss after mini-batch  1631: 0.009
# Loss after mini-batch  1641: 0.009
# Loss after mini-batch  1651: 0.008
# Loss after mini-batch  1661: 0.009
# Loss after mini-batch  1671: 0.010
# Loss after mini-batch  1681: 0.009
# Loss after mini-batch  1691: 0.009
# Loss after mini-batch  1701: 0.008
# Loss after mini-batch  1711: 0.009
# Loss after mini-batch  1721: 0.009
# Loss after mini-batch  1731: 0.009
# Loss after mini-batch  1741: 0.009
# Loss after mini-batch  1751: 0.009
# Loss after mini-batch  1761: 0.009
# Loss after mini-batch  1771: 0.010
# Loss after mini-batch  1781: 0.008
# Loss after mini-batch  1791: 0.008
# Loss after mini-batch  1801: 0.009
# Loss after mini-batch  1811: 0.008
# Loss after mini-batch  1821: 0.009
# Loss after mini-batch  1831: 0.009
# Loss after mini-batch  1841: 0.008
# Loss after mini-batch  1851: 0.009
# Loss after mini-batch  1861: 0.008
# Loss after mini-batch  1871: 0.009
# Loss after mini-batch  1881: 0.009
# Loss after mini-batch  1891: 0.008
# Loss after mini-batch  1901: 0.010
# Loss after mini-batch  1911: 0.009
# Loss after mini-batch  1921: 0.009
# Loss after mini-batch  1931: 0.009
# Loss after mini-batch  1941: 0.008
# Loss after mini-batch  1951: 0.009
# Loss after mini-batch  1961: 0.008
# Loss after mini-batch  1971: 0.009
# Loss after mini-batch  1981: 0.007
# Loss after mini-batch  1991: 0.009
# Loss after mini-batch  2001: 0.009
# Loss after mini-batch  2011: 0.009
# Loss after mini-batch  2021: 0.009
# Loss after mini-batch  2031: 0.009
# Loss after mini-batch  2041: 0.010
# Loss after mini-batch  2051: 0.009
# Loss after mini-batch  2061: 0.008
# Loss after mini-batch  2071: 0.009
# Loss after mini-batch  2081: 0.010
# Loss after mini-batch  2091: 0.009
# Loss after mini-batch  2101: 0.009
# Loss after mini-batch  2111: 0.008
# Loss after mini-batch  2121: 0.008
# Loss after mini-batch  2131: 0.009
# Loss after mini-batch  2141: 0.009
# Loss after mini-batch  2151: 0.009
# Loss after mini-batch  2161: 0.009
# Loss after mini-batch  2171: 0.010
# Loss after mini-batch  2181: 0.008
# Loss after mini-batch  2191: 0.007
# Loss after mini-batch  2201: 0.009
# Loss after mini-batch  2211: 0.009
# Loss after mini-batch  2221: 0.009
# Loss after mini-batch  2231: 0.010
# Loss after mini-batch  2241: 0.008
# Loss after mini-batch  2251: 0.009
# Loss after mini-batch  2261: 0.008
# Loss after mini-batch  2271: 0.009
# Loss after mini-batch  2281: 0.009
# Loss after mini-batch  2291: 0.010
# Loss after mini-batch  2301: 0.007
# Loss after mini-batch  2311: 0.010
# Loss after mini-batch  2321: 0.009
# Loss after mini-batch  2331: 0.009
# Loss after mini-batch  2341: 0.009
# Loss after mini-batch  2351: 0.008
# Loss after mini-batch  2361: 0.008
# Loss after mini-batch  2371: 0.008
# Loss after mini-batch  2381: 0.009
# Loss after mini-batch  2391: 0.009
# Loss after mini-batch  2401: 0.009
# Loss after mini-batch  2411: 0.009
# Loss after mini-batch  2421: 0.009
# Loss after mini-batch  2431: 0.008
# Loss after mini-batch  2441: 0.010
# Loss after mini-batch  2451: 0.008
# Loss after mini-batch  2461: 0.008
# Loss after mini-batch  2471: 0.009
# Loss after mini-batch  2481: 0.009
# Loss after mini-batch  2491: 0.009
# Loss after mini-batch  2501: 0.008
# Loss after mini-batch  2511: 0.009
# Loss after mini-batch  2521: 0.009
# Loss after mini-batch  2531: 0.009
# Loss after mini-batch  2541: 0.009
# Loss after mini-batch  2551: 0.008
# Loss after mini-batch  2561: 0.010
# Loss after mini-batch  2571: 0.009
# Loss after mini-batch  2581: 0.008
# Loss after mini-batch  2591: 0.008
# Loss after mini-batch  2601: 0.009
# Loss after mini-batch  2611: 0.008
# Loss after mini-batch  2621: 0.008
# Loss after mini-batch  2631: 0.008
# Loss after mini-batch  2641: 0.009
# Loss after mini-batch  2651: 0.010
# Loss after mini-batch  2661: 0.008
# Loss after mini-batch  2671: 0.008
# Loss after mini-batch  2681: 0.008
# Loss after mini-batch  2691: 0.009
# Loss after mini-batch  2701: 0.009
# Loss after mini-batch  2711: 0.009
# Loss after mini-batch  2721: 0.008
# Loss after mini-batch  2731: 0.008
# Loss after mini-batch  2741: 0.008
# Loss after mini-batch  2751: 0.009
# Loss after mini-batch  2761: 0.010
# Loss after mini-batch  2771: 0.007
# Loss after mini-batch  2781: 0.009
# Loss after mini-batch  2791: 0.009
# Epoch 3 finished
# Starting Epoch 4
# Loss after mini-batch     1: 0.001
# Loss after mini-batch    11: 0.008
# Loss after mini-batch    21: 0.009
# Loss after mini-batch    31: 0.008
# Loss after mini-batch    41: 0.008
# Loss after mini-batch    51: 0.008
# Loss after mini-batch    61: 0.008
# Loss after mini-batch    71: 0.008
# Loss after mini-batch    81: 0.008
# Loss after mini-batch    91: 0.008
# Loss after mini-batch   101: 0.009
# Loss after mini-batch   111: 0.008
# Loss after mini-batch   121: 0.009
# Loss after mini-batch   131: 0.009
# Loss after mini-batch   141: 0.008
# Loss after mini-batch   151: 0.008
# Loss after mini-batch   161: 0.008
# Loss after mini-batch   171: 0.008
# Loss after mini-batch   181: 0.008
# Loss after mini-batch   191: 0.009
# Loss after mini-batch   201: 0.009
# Loss after mini-batch   211: 0.008
# Loss after mini-batch   221: 0.008
# Loss after mini-batch   231: 0.008
# Loss after mini-batch   241: 0.009
# Loss after mini-batch   251: 0.008
# Loss after mini-batch   261: 0.007
# Loss after mini-batch   271: 0.008
# Loss after mini-batch   281: 0.008
# Loss after mini-batch   291: 0.008
# Loss after mini-batch   301: 0.009
# Loss after mini-batch   311: 0.008
# Loss after mini-batch   321: 0.007
# Loss after mini-batch   331: 0.008
# Loss after mini-batch   341: 0.009
# Loss after mini-batch   351: 0.009
# Loss after mini-batch   361: 0.009
# Loss after mini-batch   371: 0.008
# Loss after mini-batch   381: 0.009
# Loss after mini-batch   391: 0.008
# Loss after mini-batch   401: 0.008
# Loss after mini-batch   411: 0.007
# Loss after mini-batch   421: 0.009
# Loss after mini-batch   431: 0.007
# Loss after mini-batch   441: 0.009
# Loss after mini-batch   451: 0.008
# Loss after mini-batch   461: 0.008
# Loss after mini-batch   471: 0.007
# Loss after mini-batch   481: 0.008
# Loss after mini-batch   491: 0.009
# Loss after mini-batch   501: 0.009
# Loss after mini-batch   511: 0.007
# Loss after mini-batch   521: 0.009
# Loss after mini-batch   531: 0.007
# Loss after mini-batch   541: 0.007
# Loss after mini-batch   551: 0.008
# Loss after mini-batch   561: 0.007
# Loss after mini-batch   571: 0.008
# Loss after mini-batch   581: 0.007
# Loss after mini-batch   591: 0.008
# Loss after mini-batch   601: 0.007
# Loss after mini-batch   611: 0.007
# Loss after mini-batch   621: 0.009
# Loss after mini-batch   631: 0.008
# Loss after mini-batch   641: 0.008
# Loss after mini-batch   651: 0.008
# Loss after mini-batch   661: 0.009
# Loss after mini-batch   671: 0.009
# Loss after mini-batch   681: 0.008
# Loss after mini-batch   691: 0.008
# Loss after mini-batch   701: 0.008
# Loss after mini-batch   711: 0.008
# Loss after mini-batch   721: 0.008
# Loss after mini-batch   731: 0.009
# Loss after mini-batch   741: 0.007
# Loss after mini-batch   751: 0.008
# Loss after mini-batch   761: 0.007
# Loss after mini-batch   771: 0.007
# Loss after mini-batch   781: 0.008
# Loss after mini-batch   791: 0.009
# Loss after mini-batch   801: 0.008
# Loss after mini-batch   811: 0.008
# Loss after mini-batch   821: 0.008
# Loss after mini-batch   831: 0.008
# Loss after mini-batch   841: 0.009
# Loss after mini-batch   851: 0.008
# Loss after mini-batch   861: 0.008
# Loss after mini-batch   871: 0.008
# Loss after mini-batch   881: 0.008
# Loss after mini-batch   891: 0.008
# Loss after mini-batch   901: 0.009
# Loss after mini-batch   911: 0.008
# Loss after mini-batch   921: 0.007
# Loss after mini-batch   931: 0.009
# Loss after mini-batch   941: 0.008
# Loss after mini-batch   951: 0.007
# Loss after mini-batch   961: 0.009
# Loss after mini-batch   971: 0.007
# Loss after mini-batch   981: 0.008
# Loss after mini-batch   991: 0.008
# Loss after mini-batch  1001: 0.008
# Loss after mini-batch  1011: 0.009
# Loss after mini-batch  1021: 0.007
# Loss after mini-batch  1031: 0.008
# Loss after mini-batch  1041: 0.008
# Loss after mini-batch  1051: 0.008
# Loss after mini-batch  1061: 0.008
# Loss after mini-batch  1071: 0.008
# Loss after mini-batch  1081: 0.008
# Loss after mini-batch  1091: 0.007
# Loss after mini-batch  1101: 0.008
# Loss after mini-batch  1111: 0.007
# Loss after mini-batch  1121: 0.008
# Loss after mini-batch  1131: 0.009
# Loss after mini-batch  1141: 0.008
# Loss after mini-batch  1151: 0.008
# Loss after mini-batch  1161: 0.007
# Loss after mini-batch  1171: 0.007
# Loss after mini-batch  1181: 0.008
# Loss after mini-batch  1191: 0.007
# Loss after mini-batch  1201: 0.008
# Loss after mini-batch  1211: 0.008
# Loss after mini-batch  1221: 0.007
# Loss after mini-batch  1231: 0.008
# Loss after mini-batch  1241: 0.006
# Loss after mini-batch  1251: 0.008
# Loss after mini-batch  1261: 0.008
# Loss after mini-batch  1271: 0.008
# Loss after mini-batch  1281: 0.007
# Loss after mini-batch  1291: 0.009
# Loss after mini-batch  1301: 0.008
# Loss after mini-batch  1311: 0.007
# Loss after mini-batch  1321: 0.007
# Loss after mini-batch  1331: 0.008
# Loss after mini-batch  1341: 0.007
# Loss after mini-batch  1351: 0.009
# Loss after mini-batch  1361: 0.008
# Loss after mini-batch  1371: 0.008
# Loss after mini-batch  1381: 0.007
# Loss after mini-batch  1391: 0.007
# Loss after mini-batch  1401: 0.007
# Loss after mini-batch  1411: 0.008
# Loss after mini-batch  1421: 0.008
# Loss after mini-batch  1431: 0.008
# Loss after mini-batch  1441: 0.008
# Loss after mini-batch  1451: 0.008
# Loss after mini-batch  1461: 0.007
# Loss after mini-batch  1471: 0.008
# Loss after mini-batch  1481: 0.007
# Loss after mini-batch  1491: 0.008
# Loss after mini-batch  1501: 0.007
# Loss after mini-batch  1511: 0.008
# Loss after mini-batch  1521: 0.008
# Loss after mini-batch  1531: 0.008
# Loss after mini-batch  1541: 0.008
# Loss after mini-batch  1551: 0.008
# Loss after mini-batch  1561: 0.008
# Loss after mini-batch  1571: 0.007
# Loss after mini-batch  1581: 0.008
# Loss after mini-batch  1591: 0.008
# Loss after mini-batch  1601: 0.008
# Loss after mini-batch  1611: 0.006
# Loss after mini-batch  1621: 0.007
# Loss after mini-batch  1631: 0.008
# Loss after mini-batch  1641: 0.007
# Loss after mini-batch  1651: 0.006
# Loss after mini-batch  1661: 0.008
# Loss after mini-batch  1671: 0.007
# Loss after mini-batch  1681: 0.007
# Loss after mini-batch  1691: 0.008
# Loss after mini-batch  1701: 0.007
# Loss after mini-batch  1711: 0.008
# Loss after mini-batch  1721: 0.006
# Loss after mini-batch  1731: 0.008
# Loss after mini-batch  1741: 0.006
# Loss after mini-batch  1751: 0.008
# Loss after mini-batch  1761: 0.008
# Loss after mini-batch  1771: 0.006
# Loss after mini-batch  1781: 0.006
# Loss after mini-batch  1791: 0.008
# Loss after mini-batch  1801: 0.007
# Loss after mini-batch  1811: 0.007
# Loss after mini-batch  1821: 0.007
# Loss after mini-batch  1831: 0.007
# Loss after mini-batch  1841: 0.007
# Loss after mini-batch  1851: 0.007
# Loss after mini-batch  1861: 0.007
# Loss after mini-batch  1871: 0.007
# Loss after mini-batch  1881: 0.007
# Loss after mini-batch  1891: 0.007
# Loss after mini-batch  1901: 0.007
# Loss after mini-batch  1911: 0.007
# Loss after mini-batch  1921: 0.007
# Loss after mini-batch  1931: 0.008
# Loss after mini-batch  1941: 0.008
# Loss after mini-batch  1951: 0.006
# Loss after mini-batch  1961: 0.008
# Loss after mini-batch  1971: 0.007
# Loss after mini-batch  1981: 0.008
# Loss after mini-batch  1991: 0.007
# Loss after mini-batch  2001: 0.008
# Loss after mini-batch  2011: 0.007
# Loss after mini-batch  2021: 0.008
# Loss after mini-batch  2031: 0.006
# Loss after mini-batch  2041: 0.009
# Loss after mini-batch  2051: 0.006
# Loss after mini-batch  2061: 0.007
# Loss after mini-batch  2071: 0.007
# Loss after mini-batch  2081: 0.007
# Loss after mini-batch  2091: 0.008
# Loss after mini-batch  2101: 0.008
# Loss after mini-batch  2111: 0.007
# Loss after mini-batch  2121: 0.007
# Loss after mini-batch  2131: 0.007
# Loss after mini-batch  2141: 0.007
# Loss after mini-batch  2151: 0.008
# Loss after mini-batch  2161: 0.007
# Loss after mini-batch  2171: 0.007
# Loss after mini-batch  2181: 0.007
# Loss after mini-batch  2191: 0.008
# Loss after mini-batch  2201: 0.008
# Loss after mini-batch  2211: 0.007
# Loss after mini-batch  2221: 0.007
# Loss after mini-batch  2231: 0.007
# Loss after mini-batch  2241: 0.007
# Loss after mini-batch  2251: 0.007
# Loss after mini-batch  2261: 0.008
# Loss after mini-batch  2271: 0.007
# Loss after mini-batch  2281: 0.007
# Loss after mini-batch  2291: 0.008
# Loss after mini-batch  2301: 0.007
# Loss after mini-batch  2311: 0.007
# Loss after mini-batch  2321: 0.006
# Loss after mini-batch  2331: 0.007
# Loss after mini-batch  2341: 0.008
# Loss after mini-batch  2351: 0.006
# Loss after mini-batch  2361: 0.006
# Loss after mini-batch  2371: 0.008
# Loss after mini-batch  2381: 0.007
# Loss after mini-batch  2391: 0.007
# Loss after mini-batch  2401: 0.007
# Loss after mini-batch  2411: 0.007
# Loss after mini-batch  2421: 0.009
# Loss after mini-batch  2431: 0.007
# Loss after mini-batch  2441: 0.007
# Loss after mini-batch  2451: 0.007
# Loss after mini-batch  2461: 0.007
# Loss after mini-batch  2471: 0.008
# Loss after mini-batch  2481: 0.007
# Loss after mini-batch  2491: 0.007
# Loss after mini-batch  2501: 0.007
# Loss after mini-batch  2511: 0.007
# Loss after mini-batch  2521: 0.007
# Loss after mini-batch  2531: 0.007
# Loss after mini-batch  2541: 0.006
# Loss after mini-batch  2551: 0.007
# Loss after mini-batch  2561: 0.007
# Loss after mini-batch  2571: 0.007
# Loss after mini-batch  2581: 0.006
# Loss after mini-batch  2591: 0.006
# Loss after mini-batch  2601: 0.007
# Loss after mini-batch  2611: 0.007
# Loss after mini-batch  2621: 0.007
# Loss after mini-batch  2631: 0.007
# Loss after mini-batch  2641: 0.006
# Loss after mini-batch  2651: 0.008
# Loss after mini-batch  2661: 0.006
# Loss after mini-batch  2671: 0.006
# Loss after mini-batch  2681: 0.007
# Loss after mini-batch  2691: 0.007
# Loss after mini-batch  2701: 0.006
# Loss after mini-batch  2711: 0.007
# Loss after mini-batch  2721: 0.006
# Loss after mini-batch  2731: 0.007
# Loss after mini-batch  2741: 0.007
# Loss after mini-batch  2751: 0.007
# Loss after mini-batch  2761: 0.007
# Loss after mini-batch  2771: 0.006
# Loss after mini-batch  2781: 0.007
# Loss after mini-batch  2791: 0.007
# Epoch 4 finished
# Starting Epoch 5
# Loss after mini-batch     1: 0.001
# Loss after mini-batch    11: 0.006
# Loss after mini-batch    21: 0.007
# Loss after mini-batch    31: 0.007
# Loss after mini-batch    41: 0.007
# Loss after mini-batch    51: 0.007
# Loss after mini-batch    61: 0.006
# Loss after mini-batch    71: 0.007
# Loss after mini-batch    81: 0.007
# Loss after mini-batch    91: 0.006
# Loss after mini-batch   101: 0.008
# Loss after mini-batch   111: 0.007
# Loss after mini-batch   121: 0.007
# Loss after mini-batch   131: 0.007
# Loss after mini-batch   141: 0.007
# Loss after mini-batch   151: 0.007
# Loss after mini-batch   161: 0.006
# Loss after mini-batch   171: 0.007
# Loss after mini-batch   181: 0.006
# Loss after mini-batch   191: 0.006
# Loss after mini-batch   201: 0.007
# Loss after mini-batch   211: 0.009
# Loss after mini-batch   221: 0.006
# Loss after mini-batch   231: 0.006
# Loss after mini-batch   241: 0.007
# Loss after mini-batch   251: 0.008
# Loss after mini-batch   261: 0.008
# Loss after mini-batch   271: 0.006
# Loss after mini-batch   281: 0.007
# Loss after mini-batch   291: 0.006
# Loss after mini-batch   301: 0.007
# Loss after mini-batch   311: 0.006
# Loss after mini-batch   321: 0.006
# Loss after mini-batch   331: 0.006
# Loss after mini-batch   341: 0.007
# Loss after mini-batch   351: 0.007
# Loss after mini-batch   361: 0.007
# Loss after mini-batch   371: 0.006
# Loss after mini-batch   381: 0.007
# Loss after mini-batch   391: 0.007
# Loss after mini-batch   401: 0.007
# Loss after mini-batch   411: 0.007
# Loss after mini-batch   421: 0.006
# Loss after mini-batch   431: 0.007
# Loss after mini-batch   441: 0.007
# Loss after mini-batch   451: 0.006
# Loss after mini-batch   461: 0.008
# Loss after mini-batch   471: 0.007
# Loss after mini-batch   481: 0.007
# Loss after mini-batch   491: 0.007
# Loss after mini-batch   501: 0.006
# Loss after mini-batch   511: 0.007
# Loss after mini-batch   521: 0.007
# Loss after mini-batch   531: 0.008
# Loss after mini-batch   541: 0.008
# Loss after mini-batch   551: 0.007
# Loss after mini-batch   561: 0.007
# Loss after mini-batch   571: 0.007
# Loss after mini-batch   581: 0.007
# Loss after mini-batch   591: 0.007
# Loss after mini-batch   601: 0.006
# Loss after mini-batch   611: 0.006
# Loss after mini-batch   621: 0.007
# Loss after mini-batch   631: 0.007
# Loss after mini-batch   641: 0.007
# Loss after mini-batch   651: 0.007
# Loss after mini-batch   661: 0.006
# Loss after mini-batch   671: 0.006
# Loss after mini-batch   681: 0.005
# Loss after mini-batch   691: 0.007
# Loss after mini-batch   701: 0.007
# Loss after mini-batch   711: 0.006
# Loss after mini-batch   721: 0.007
# Loss after mini-batch   731: 0.007
# Loss after mini-batch   741: 0.007
# Loss after mini-batch   751: 0.006
# Loss after mini-batch   761: 0.006
# Loss after mini-batch   771: 0.006
# Loss after mini-batch   781: 0.007
# Loss after mini-batch   791: 0.006
# Loss after mini-batch   801: 0.006
# Loss after mini-batch   811: 0.007
# Loss after mini-batch   821: 0.006
# Loss after mini-batch   831: 0.008
# Loss after mini-batch   841: 0.007
# Loss after mini-batch   851: 0.007
# Loss after mini-batch   861: 0.005
# Loss after mini-batch   871: 0.007
# Loss after mini-batch   881: 0.006
# Loss after mini-batch   891: 0.006
# Loss after mini-batch   901: 0.007
# Loss after mini-batch   911: 0.007
# Loss after mini-batch   921: 0.006
# Loss after mini-batch   931: 0.006
# Loss after mini-batch   941: 0.007
# Loss after mini-batch   951: 0.006
# Loss after mini-batch   961: 0.007
# Loss after mini-batch   971: 0.007
# Loss after mini-batch   981: 0.006
# Loss after mini-batch   991: 0.005
# Loss after mini-batch  1001: 0.006
# Loss after mini-batch  1011: 0.007
# Loss after mini-batch  1021: 0.006
# Loss after mini-batch  1031: 0.006
# Loss after mini-batch  1041: 0.006
# Loss after mini-batch  1051: 0.005
# Loss after mini-batch  1061: 0.006
# Loss after mini-batch  1071: 0.007
# Loss after mini-batch  1081: 0.007
# Loss after mini-batch  1091: 0.007
# Loss after mini-batch  1101: 0.007
# Loss after mini-batch  1111: 0.008
# Loss after mini-batch  1121: 0.006
# Loss after mini-batch  1131: 0.007
# Loss after mini-batch  1141: 0.006
# Loss after mini-batch  1151: 0.006
# Loss after mini-batch  1161: 0.006
# Loss after mini-batch  1171: 0.007
# Loss after mini-batch  1181: 0.006
# Loss after mini-batch  1191: 0.007
# Loss after mini-batch  1201: 0.007
# Loss after mini-batch  1211: 0.008
# Loss after mini-batch  1221: 0.007
# Loss after mini-batch  1231: 0.007
# Loss after mini-batch  1241: 0.007
# Loss after mini-batch  1251: 0.007
# Loss after mini-batch  1261: 0.007
# Loss after mini-batch  1271: 0.007
# Loss after mini-batch  1281: 0.007
# Loss after mini-batch  1291: 0.006
# Loss after mini-batch  1301: 0.006
# Loss after mini-batch  1311: 0.006
# Loss after mini-batch  1321: 0.006
# Loss after mini-batch  1331: 0.006
# Loss after mini-batch  1341: 0.005
# Loss after mini-batch  1351: 0.006
# Loss after mini-batch  1361: 0.007
# Loss after mini-batch  1371: 0.006
# Loss after mini-batch  1381: 0.007
# Loss after mini-batch  1391: 0.007
# Loss after mini-batch  1401: 0.006
# Loss after mini-batch  1411: 0.006
# Loss after mini-batch  1421: 0.006
# Loss after mini-batch  1431: 0.006
# Loss after mini-batch  1441: 0.007
# Loss after mini-batch  1451: 0.007
# Loss after mini-batch  1461: 0.007
# Loss after mini-batch  1471: 0.006
# Loss after mini-batch  1481: 0.007
# Loss after mini-batch  1491: 0.006
# Loss after mini-batch  1501: 0.007
# Loss after mini-batch  1511: 0.007
# Loss after mini-batch  1521: 0.006
# Loss after mini-batch  1531: 0.006
# Loss after mini-batch  1541: 0.007
# Loss after mini-batch  1551: 0.006
# Loss after mini-batch  1561: 0.006
# Loss after mini-batch  1571: 0.007
# Loss after mini-batch  1581: 0.007
# Loss after mini-batch  1591: 0.006
# Loss after mini-batch  1601: 0.006
# Loss after mini-batch  1611: 0.007
# Loss after mini-batch  1621: 0.006
# Loss after mini-batch  1631: 0.006
# Loss after mini-batch  1641: 0.007
# Loss after mini-batch  1651: 0.007
# Loss after mini-batch  1661: 0.007
# Loss after mini-batch  1671: 0.006
# Loss after mini-batch  1681: 0.007
# Loss after mini-batch  1691: 0.006
# Loss after mini-batch  1701: 0.007
# Loss after mini-batch  1711: 0.006
# Loss after mini-batch  1721: 0.007
# Loss after mini-batch  1731: 0.006
# Loss after mini-batch  1741: 0.006
# Loss after mini-batch  1751: 0.006
# Loss after mini-batch  1761: 0.007
# Loss after mini-batch  1771: 0.007
# Loss after mini-batch  1781: 0.007
# Loss after mini-batch  1791: 0.006
# Loss after mini-batch  1801: 0.006
# Loss after mini-batch  1811: 0.006
# Loss after mini-batch  1821: 0.007
# Loss after mini-batch  1831: 0.008
# Loss after mini-batch  1841: 0.006
# Loss after mini-batch  1851: 0.006
# Loss after mini-batch  1861: 0.006
# Loss after mini-batch  1871: 0.007
# Loss after mini-batch  1881: 0.006
# Loss after mini-batch  1891: 0.005
# Loss after mini-batch  1901: 0.007
# Loss after mini-batch  1911: 0.006
# Loss after mini-batch  1921: 0.006
# Loss after mini-batch  1931: 0.007
# Loss after mini-batch  1941: 0.007
# Loss after mini-batch  1951: 0.006
# Loss after mini-batch  1961: 0.006
# Loss after mini-batch  1971: 0.005
# Loss after mini-batch  1981: 0.006
# Loss after mini-batch  1991: 0.007
# Loss after mini-batch  2001: 0.006
# Loss after mini-batch  2011: 0.005
# Loss after mini-batch  2021: 0.007
# Loss after mini-batch  2031: 0.006
# Loss after mini-batch  2041: 0.007
# Loss after mini-batch  2051: 0.007
# Loss after mini-batch  2061: 0.006
# Loss after mini-batch  2071: 0.007
# Loss after mini-batch  2081: 0.006
# Loss after mini-batch  2091: 0.006
# Loss after mini-batch  2101: 0.006
# Loss after mini-batch  2111: 0.006
# Loss after mini-batch  2121: 0.006
# Loss after mini-batch  2131: 0.007
# Loss after mini-batch  2141: 0.007
# Loss after mini-batch  2151: 0.005
# Loss after mini-batch  2161: 0.007
# Loss after mini-batch  2171: 0.006
# Loss after mini-batch  2181: 0.006
# Loss after mini-batch  2191: 0.006
# Loss after mini-batch  2201: 0.005
# Loss after mini-batch  2211: 0.005
# Loss after mini-batch  2221: 0.006
# Loss after mini-batch  2231: 0.007
# Loss after mini-batch  2241: 0.006
# Loss after mini-batch  2251: 0.006
# Loss after mini-batch  2261: 0.005
# Loss after mini-batch  2271: 0.006
# Loss after mini-batch  2281: 0.007
# Loss after mini-batch  2291: 0.006
# Loss after mini-batch  2301: 0.006
# Loss after mini-batch  2311: 0.007
# Loss after mini-batch  2321: 0.006
# Loss after mini-batch  2331: 0.007
# Loss after mini-batch  2341: 0.007
# Loss after mini-batch  2351: 0.006
# Loss after mini-batch  2361: 0.007
# Loss after mini-batch  2371: 0.005
# Loss after mini-batch  2381: 0.006
# Loss after mini-batch  2391: 0.006
# Loss after mini-batch  2401: 0.007
# Loss after mini-batch  2411: 0.005
# Loss after mini-batch  2421: 0.005
# Loss after mini-batch  2431: 0.005
# Loss after mini-batch  2441: 0.006
# Loss after mini-batch  2451: 0.006
# Loss after mini-batch  2461: 0.006
# Loss after mini-batch  2471: 0.006
# Loss after mini-batch  2481: 0.006
# Loss after mini-batch  2491: 0.007
# Loss after mini-batch  2501: 0.006
# Loss after mini-batch  2511: 0.006
# Loss after mini-batch  2521: 0.006
# Loss after mini-batch  2531: 0.006
# Loss after mini-batch  2541: 0.007
# Loss after mini-batch  2551: 0.005
# Loss after mini-batch  2561: 0.006
# Loss after mini-batch  2571: 0.005
# Loss after mini-batch  2581: 0.006
# Loss after mini-batch  2591: 0.006
# Loss after mini-batch  2601: 0.006
# Loss after mini-batch  2611: 0.006
# Loss after mini-batch  2621: 0.006
# Loss after mini-batch  2631: 0.006
# Loss after mini-batch  2641: 0.005
# Loss after mini-batch  2651: 0.005
# Loss after mini-batch  2661: 0.006
# Loss after mini-batch  2671: 0.006
# Loss after mini-batch  2681: 0.006
# Loss after mini-batch  2691: 0.006
# Loss after mini-batch  2701: 0.006
# Loss after mini-batch  2711: 0.006
# Loss after mini-batch  2721: 0.006
# Loss after mini-batch  2731: 0.005
# Loss after mini-batch  2741: 0.006
# Loss after mini-batch  2751: 0.007
# Loss after mini-batch  2761: 0.006
# Loss after mini-batch  2771: 0.006
# Loss after mini-batch  2781: 0.005
# Loss after mini-batch  2791: 0.007
# Epoch 5 finished
# Training has completed

# %%
test_data = torch.from_numpy(X_test).float()
test_targets = torch.from_numpy(y_test).float()

# %%
mlp.eval()
# Out:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=12, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
with torch.no_grad():
    outputs = mlp(test_data)
    predicted_labels = outputs.squeeze().tolist()

predicted_labels = np.array(predicted_labels)
test_targets = np.array(test_targets)

rmse = root_mean_squared_error(test_targets, predicted_labels)
r2 = r2_score(test_targets, predicted_labels)
print("Root Mean Squared Error:", rmse)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 0.510135305686586
# R2 Score: 0.623430872605933
